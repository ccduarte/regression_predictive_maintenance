# %% [markdown]
# Predictive Maintenance - Paper Co

# %%
import pandas as pd
import numpy as np

# %%
columns_names =["Asset_id", "runtime", "Setting1", 'Setting2', 'Setting3', 'Tag1', 'Tag2', 'Tag3', 'Tag4', 
       'Tag5','Tag6', 'Tag7', 'Tag8', 'Tag9', 'Tag10', 'Tag11', 'Tag12', 'Tag13', 
       'Tag14', 'Tag15', 'Tag16', 'Tag17', 'Tag18', 'Tag19', 'Tag20', 'Tag21']

# %%
train = pd.read_csv('C:/Users/cintia.duarte/Desktop/Cintia/Cases/Suzano/dataset_pred_maint/PM_train.txt', header=None, delimiter=r"\s+", names=columns_names)
##test = pd.read_csv('C:/Users/cintia.duarte/Desktop/Cintia/Cases/Suzano/dataset_pred_maint/PM_test.txt', header=None, delimiter=r"\s+", names=columns_names)

# %%
train
# Out:
#        Asset_id  runtime  Setting1  Setting2  Setting3    Tag1    Tag2  \
# 0             1        1   -0.0007   -0.0004     100.0  518.67  641.82
# 1             1        2    0.0019   -0.0003     100.0  518.67  642.15
# 2             1        3   -0.0043    0.0003     100.0  518.67  642.35
# 3             1        4    0.0007    0.0000     100.0  518.67  642.35
# 4             1        5   -0.0019   -0.0002     100.0  518.67  642.37
# ...         ...      ...       ...       ...       ...     ...     ...
# 20626       100      196   -0.0004   -0.0003     100.0  518.67  643.49
# 20627       100      197   -0.0016   -0.0005     100.0  518.67  643.54
# 20628       100      198    0.0004    0.0000     100.0  518.67  643.42
# 20629       100      199   -0.0011    0.0003     100.0  518.67  643.23
# 20630       100      200   -0.0032   -0.0005     100.0  518.67  643.85
#
#           Tag3     Tag4   Tag5  ...   Tag12    Tag13    Tag14   Tag15  Tag16  \
# ...

# %%
## Quantidade de ciclos por id
df_cycle = train.groupby('Asset_id')['runtime'].count()
df_cycle = df_cycle.reset_index()

# %%
df_cycle
# Out:
#     Asset_id  runtime
# 0          1      192
# 1          2      287
# 2          3      179
# 3          4      189
# 4          5      269
# ..       ...      ...
# 95        96      336
# 96        97      202
# 97        98      156
# 98        99      185
# 99       100      200
#
# [100 rows x 2 columns]
